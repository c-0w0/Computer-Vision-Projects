# %%
# General import
import os

# 3rd-party import
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Local import

# %%
img_path = '../data/cat.jpg'
img = cv2.imread(img_path)

# %%
print(f"Image type: {type(img)}")
print(f"Is image a NumPy array?: {isinstance(img, np.ndarray)}")
# Out:
# Image type: <class 'numpy.ndarray'>
# Is image a NumPy array?: True

# %%
# plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.title("Image")
plt.axis('off')
plt.show()

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

ax1.imshow(img_rgb)
ax1.set_title("RGB image")
ax1.axis('off')

ax2.imshow(img_gray, cmap='gray')
ax2.set_title("Grayscale image")
ax2.axis('off')

ax3.imshow(img_hsv)
ax3.set_title("HSV image")
ax3.axis('off')

plt.tight_layout()
plt.show()

# %%
# fig, axes = plt.subplots(1, 3, figsize=(15, 5))
# axes = axes.flatten()  # Convert 2D grid to 1D array of 6 axes

# images = [img_rgb, img_gray, img_hsv]
# titles = ["RGB", "Grayscale", "HSV"]

# for ax, img, title in zip(axes, images, titles):
#     ax.imshow(img)
#     ax.set_title(title)
#     ax.axis('off')

# plt.tight_layout()
# plt.show()
